# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.2 🚀 Python-3.10.12 torch-2.0.0 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 5359.4/8062.4 GB disk)

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2732630266601028536
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 16274030592
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 11132508558912521207
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"
#  xla_global_id: 416903419]

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='/kaggle/input/rgb-yaml-file/rgb_dataset_kaggle_updated.yaml', epochs=100, save_period=2, device=0, project='RGB_Object_detection', name='19Jan2024_model_1', optimizer = 'Adam')  # train the model
results = model.val()  # evaluate model performance on the validation set
#results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
#results = model.export(format='onnx')  # export the model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# !zip -r rgb_file.zip /kaggle/working
# Out:
#   adding: kaggle/working/ (stored 0%)
#   adding: kaggle/working/RGB_Object_detection/ (stored 0%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/ (stored 0%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/F1_curve.png (deflated 8%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/val_batch0_labels.jpg (deflated 5%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/val_batch0_pred.jpg (deflated 5%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/PR_curve.png (deflated 9%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/val_batch2_labels.jpg (deflated 5%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/P_curve.png (deflated 6%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/val_batch1_labels.jpg (deflated 5%)
#   adding: kaggle/working/RGB_Object_detection/19Jan2024_model_12/val_batch1_pred.jpg (deflated 5%)
# ...

# %%
# !rm -rf /kaggle/working/rgb_file.zip

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# Use the model
results = model.train(data='/kaggle/input/grd-dataset-kaggle/grd_dataset_kaggle_updated.yaml', epochs=100, save_period=2, device=0, project='GRD_Object_detection', name='19Jan2024_model_1_1', optimizer = 'Adam')  # train the model
results = model.val()  # evaluate model performance on the validation set
#results = model('https://ultralytics.com/images/bus.jpg')  # predict on an image
#results = model.export(format='onnx')  # export the model to ONNX format
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# !zip -r grd_file.zip /kaggle/working/GRD_Object_detection
# Out:
#   adding: kaggle/working/GRD_Object_detection/ (stored 0%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/ (stored 0%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/F1_curve.png (deflated 9%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/val_batch0_labels.jpg (deflated 8%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/val_batch0_pred.jpg (deflated 9%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/events.out.tfevents.1705685952.323ef985c47f.226.1 (deflated 89%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/train_batch15211.jpg (deflated 18%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/results.png (deflated 7%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/labels.jpg (deflated 20%)
#   adding: kaggle/working/GRD_Object_detection/19Jan2024_model_1_1/results.csv (deflated 86%)
# ...

# %%
# !rm -rf /kaggle/working/grd_file.zip
